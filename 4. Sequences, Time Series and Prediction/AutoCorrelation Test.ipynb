# %%
import pandas as pd
from pandas.plotting import autocorrelation_plot
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot

# %% [markdown]
# ### AutoCorrelation

# %% [markdown]
# "Auto-correlation is something's **auto(self)** correlation ;), or <br>
# how correlated is something with itself compared to a **past observation.**
#
#
# In general, an autocorrelation of lag n, is the correlation of each observation in a series with the observation n before it.

# %% [markdown]
# Autocorrelation plots **graph autocorrelations of time series data for different lags**.
# Autocorrelation is the correlation of a time series with the same time series lagged"

# %%
df = pd.read_csv("sunspots.csv", parse_dates=["Date"], index_col="Date")
series = df["Monthly Mean Total Sunspot Number"].asfreq("1M")
series.head()
# Out:
# Date
# 1749-01-31     96.7
# 1749-02-28    104.3
# 1749-03-31    116.7
# 1749-04-30     92.8
# 1749-05-31    141.7
# Freq: M, Name: Monthly Mean Total Sunspot Number, dtype: float64

# %%
lag_plot(series)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
plt.clf()
fig, ax = plt.subplots(figsize=(15, 5))
autocorrelation_plot(series, ax=ax)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig, ax = plt.subplots(figsize=(15, 10))
plot_pacf(series, lags=100, use_vlines=False, ax=ax)

# %%
series.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
autocorrelation_plot(series)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
# making Time series
spacing = np.linspace(-5 * np.pi, 5 * np.pi, num=100)
s = pd.Series(0.7 * np.random.rand(100) + 0.3 * np.sin(spacing))
  
# Creating Autocorrelation plot
x = pd.plotting.autocorrelation_plot(s)
  
# ploting the Curve
x.plot()
  
# Display
plt.show()

# %%
spacing
# Out:
# array([-15.70796327, -15.39063068, -15.07329809, -14.75596549,
#        -14.4386329 , -14.12130031, -13.80396772, -13.48663513,
#        -13.16930254, -12.85196995, -12.53463736, -12.21730476,
#        -11.89997217, -11.58263958, -11.26530699, -10.9479744 ,
#        -10.63064181, -10.31330922,  -9.99597663,  -9.67864403,
#         -9.36131144,  -9.04397885,  -8.72664626,  -8.40931367,
#         -8.09198108,  -7.77464849,  -7.45731589,  -7.1399833 ,
#         -6.82265071,  -6.50531812,  -6.18798553,  -5.87065294,
#         -5.55332035,  -5.23598776,  -4.91865516,  -4.60132257,
#         -4.28398998,  -3.96665739,  -3.6493248 ,  -3.33199221,
#         -3.01465962,  -2.69732703,  -2.37999443,  -2.06266184,
#         -1.74532925,  -1.42799666,  -1.11066407,  -0.79333148,
#         -0.47599889,  -0.1586663 ,   0.1586663 ,   0.47599889,
#          0.79333148,   1.11066407,   1.42799666,   1.74532925,
#          2.06266184,   2.37999443,   2.69732703,   3.01465962,
# ...
