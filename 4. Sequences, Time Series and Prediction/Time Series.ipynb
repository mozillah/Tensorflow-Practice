# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
time = np.arange(3*365+2)

# %%
# time

# %%
def trend(time,slope=0.1):
    series = time * slope
    return series

# %%
series=trend(time)

# %%
def plot_series(time,series):
    plt.figure(figsize=(10,6))
    plt.plot(time,series)
    plt.xlabel("time")
    plt.ylabel("series")
    plt.grid(True)
    plt.show()

# %%
plot_series(time,series)

# %%
def seasonal_pattern(season_time):
    return np.where(season_time < 0.5,
                    season_time,
                    season_time,
#                     np.cos(season_time),
#                     (season_time),

                    #                     1 / np.exp(3 * season_time)
                   )

def seasonality(time, period, amplitude=1, phase=0):
    season_time = ((time + phase) % period) / period
    
    return amplitude * seasonal_pattern(season_time)

# %%
baseline = 5
amplitude = 1
series = seasonality(time, period=365, amplitude=amplitude)
plot_series(time, series)

# %%
def seasonal_pattern(season_time):
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

# %%
def seasonality(time, period, amplitude=1, phase=0):
    print(phase)
    print(time)
    time
    season_time = ((time + phase) % period) / period
    print(season_time)
    return amplitude * seasonal_pattern(season_time)

# %%
period =365
((time +0) % period)/365
# Out:
# array([0.        , 0.00273973, 0.00547945, ..., 0.99726027, 0.        ,
#        0.00273973])

# %%
(time +0) % period / 365
# Out:
# array([0.        , 0.00273973, 0.00547945, ..., 0.99726027, 0.        ,
#        0.00273973])

# %%
plt.plot(np.arange(100),np.)

# %%
season_time = ((time + phase) % period) / period
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-5e3373465ba9> in <module>
# ----> 1 season_time = ((time + phase) % period) / period
#
# NameError: name 'phase' is not defined

# %%
season_time
# Out:
# array([   0,    1,    2, ..., 1094, 1095, 1096])
