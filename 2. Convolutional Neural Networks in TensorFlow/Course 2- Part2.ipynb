# %%
import os
import cv2

# %%
base_dir = '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

# %%
# --------------------
# Flow training images in batches of 20 using train_datagen generator
# --------------------
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=20,
                                                    class_mode='binary',
                                                    target_size=(150, 150))     
# --------------------
# Flow validation images in batches of 20 using test_datagen generator
# --------------------
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                         batch_size=20,
                                                         class_mode  = 'binary',
                                                         target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
train_cat_fnames = os.listdir( train_cats_dir)
train_dog_fnames = os.listdir( train_dogs_dir)

print(train_cat_fnames[:10])
print(train_dog_fnames[:10])
# Out:
# ['cat.684.jpg', 'cat.862.jpg', 'cat.994.jpg', 'cat.781.jpg', 'cat.192.jpg', 'cat.574.jpg', 'cat.573.jpg', 'cat.79.jpg', 'cat.771.jpg', 'cat.94.jpg']
# ['dog.574.jpg', 'dog.172.jpg', 'dog.223.jpg', 'dog.555.jpg', 'dog.220.jpg', 'dog.685.jpg', 'dog.925.jpg', 'dog.518.jpg', 'dog.399.jpg', 'dog.4.jpg']

# %%
print('total training cat images :', len(os.listdir(train_cats_dir ) ))
print('total training dog images :', len(os.listdir(train_dogs_dir ) ))

print('total validation cat images :', len(os.listdir(validation_cats_dir ) ))
print('total validation dog images :', len(os.listdir(validation_dogs_dir ) ))
# Out:
# total training cat images : 1000
# total training dog images : 1000
# total validation cat images : 500
# total validation dog images : 500

# %%
import matplotlib.pyplot as plt

nrows = ncols =4
pics =8
fig= plt.gcf()
fig.set_size_inches(nrows*4,ncols*4)

next_cat_images=[os.path.join(train_cats_dir,image) for image in train_cat_fnames[:pic_index]]
next_dog_images=[os.path.join(train_dogs_dir,image) for image in train_dog_fnames[:pic_index]]

print(next_cat_images+next_dog_images)
for i,image in enumerate(next_cat_images+next_dog_images):
    img = cv2.imread(image)
    plt.subplot(nrows,ncols,i+1)
    plt.imshow(img)
# Out:
# ['/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.684.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.862.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.994.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.781.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.192.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.574.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.573.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/cats/cat.79.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/dogs/dog.574.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/dogs/dog.172.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/dogs/dog.223.jpg', '/home/mazz/Desktop/github/DataSet/cats_and_dogs_filtered/train/dogs/dog.555.jpg', '/
# ...

# %%
import tensorflow as tf

# %%
model=tf.keras.model.Sequential([
    tf.keras.layers.Conv2D(16,(3,3))
])

# %%
tf.keras.models.load_model("/home/mazz/Desktop/github/model.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-d74c79099960> in <module>
# ----> 1 tf.keras.models.load_model("/home/mazz/Desktop/github/model.h5")
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204       if (h5py is not None and
#     205           (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 206         return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#     207                                                 compile)
#     208
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     179     model_config = f.attrs.get('model_config')
#     180     if model_config is None:
# ...

# %%
# load and evaluate a saved model
from numpy import loadtxt
from keras.models import load_model
 
# load model
model = load_model('/home/mazz/Desktop/github/model.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-2f0f0fc459f1> in <module>
#       4
#       5 # load model
# ----> 6 model = load_model('/home/mazz/Desktop/github/model.h5')
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204       if (h5py is not None and
#     205           (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 206         return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#     207                                                 compile)
#     208
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     179     model_config = f.attrs.get('model_config')
#     180     if model_config is None:
# ...
