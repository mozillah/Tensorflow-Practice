# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
# import os
# import zipfile

# local_zip = r'/home/mazz/Desktop/github/Tensorflow Practice/1. Introduction to TensorFlow/horse-or-human.zip'
# zip_ref = zipfile.ZipFile(local_zip, 'r')
# zip_ref.extractall('/horse-or-human')
# zip_ref.close()

# %%
# Directory with our training horse pictures
train_horse_dir = os.path.join(r'./1. Introduction to TensorFlow/tmp/horse-or-human/horses')

# Directory with our training human pictures
train_human_dir = os.path.join(r'./1. Introduction to TensorFlow/tmp/horse-or-human/humans')

# %%
train_horse_dir
# Out:
# '/1. Introduction to TensorFlow/tmp/horse-or-human/horses'

# %%
# /home/mazz/Desktop/github/Tensorflow Practice/1. Introduction to TensorFlow/tmp/horse-or-human

# %%
train_horse_names = os.listdir(train_horse_dir)
print(train_horse_names[:10])

train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])
# Out:
# ['horse49-9.png', 'horse08-1.png', 'horse26-2.png', 'horse22-1.png', 'horse49-6.png', 'horse41-7.png', 'horse35-6.png', 'horse22-6.png', 'horse23-8.png', 'horse45-2.png']
# ['human05-10.png', 'human14-01.png', 'human01-11.png', 'human07-19.png', 'human08-16.png', 'human12-15.png', 'human13-22.png', 'human13-07.png', 'human17-16.png', 'human08-29.png']

# %%
print('total training horse images:', len(os.listdir(train_horse_dir)))
print('total training human images:', len(os.listdir(train_human_dir)))
# Out:
# total training horse images: 500
# total training human images: 527

# %%
import cv2

# %%
path=os.path.join(train_horse_dir,train_horse_names[0])
img=cv2.imread(path)

# %%
plt.imshow(img)
cv2.imwrite("img.jpg",img[:,:,::-1])
# Out:
# True

# %%
fig, ax = plt.subplots(nrows=4, ncols=4)

for row in ax:
    for col in row:
        col.plot(x, y)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
pic_index =8
fig, ax = plt.subplots(nrows=4, ncols=4)
human_horse=[[cv2.imread(os.path.join(train_human_dir,human)),cv2.imread(os.path.join(train_horse_dir,horse))] for human,horse in zip(train_human_names[0:pic_index],train_horse_names[0:pic_index],)]

# %%
plt.imshow(human_horse[0][1])

# %%
pic_index += 8

# %%
pic_index
# Out:
# 8

# %%
for fname in train_human_names[0:8]:
    print(fname)
# Out:
# human05-10.png
# human14-01.png
# human01-11.png
# human07-19.png
# human08-16.png
# human12-15.png
# human13-22.png
# human13-07.png

# %%
len(train_human_names)
# Out:
# 527

# %%
len(train_horse_dir)
# Out:
# 26

# %%
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-8:pic_index]]

# %%
len(train_human_names)
# Out:
# 527

# %%
len(train_horse_names)
# Out:
# 500

# %%
for i ,img_path in enumerate(next_horse_pix+)

# %%
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)
pic_index += 8

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import matplotlib.pyplot as plt
f, axarr = plt.subplots(3,4)
FIRST_IMAGE=0
SECOND_IMAGE=23
THIRD_IMAGE=28
CONVOLUTION_NUMBER = 1 # Chooses the filter, i.e, the feature to detect.
from tensorflow.keras import models

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
